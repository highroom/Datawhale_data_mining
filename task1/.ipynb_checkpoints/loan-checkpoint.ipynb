# %%
#coding:utf-8
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rc('font', family='SimHei', size=13)

# %% [markdown]
# ### 1.查看数据情况

# %%
data = pd.read_csv('data.csv', encoding='gbk')

# %%
data.describe()
# Out:
#          Unnamed: 0        custid  low_volume_percent  middle_volume_percent  \
# count   4754.000000  4.754000e+03         4752.000000            4752.000000
# mean    6008.414178  1.690993e+06            0.021806               0.901294
# std     3452.071428  1.034235e+06            0.041527               0.144856
# min        5.000000  1.140000e+02            0.000000               0.000000
# 25%     3106.000000  7.593358e+05            0.010000               0.880000
# 50%     6006.500000  1.634942e+06            0.010000               0.960000
# 75%     8999.000000  2.597905e+06            0.020000               0.990000
# max    11992.000000  4.004694e+06            1.000000               1.000000
#
#        take_amount_in_later_12_month_highest  \
# count                            4754.000000
# mean                             1940.197728
# std                              3923.971494
# min                                 0.000000
# 25%                                 0.000000
# 50%                               500.000000
# 75%                              2000.000000
# max                             68000.000000
#
#        trans_amount_increase_rate_lately  trans_activity_month  \
# count                        4751.000000           4752.000000
# mean                           14.160674              0.804411
# std                           694.180473              0.196920
# min                             0.000000              0.120000
# 25%                             0.615000              0.670000
# 50%                             0.970000              0.860000
# 75%                             1.600000              1.000000
# max                         47596.740000              1.000000
#
#        trans_activity_day   transd_mcc  trans_days_interval_filter  \
# count         4752.000000  4752.000000                 4746.000000
# mean             0.365425    17.502946                   29.029920
# std              0.170196     4.475616                   22.722432
# min              0.033000     2.000000                    0.000000
# 25%              0.233000    15.000000                   16.000000
# 50%              0.350000    17.000000                   23.000000
# 75%              0.480000    20.000000                   32.000000
# max              0.941000    42.000000                  285.000000
#
#              ...         loans_max_limit  loans_avg_limit  \
# count        ...             4457.000000      4457.000000
# mean         ...             3390.038142      1820.357864
# std          ...             1474.206546       583.418291
# min          ...                0.000000         0.000000
# 25%          ...             2300.000000      1535.000000
# 50%          ...             3100.000000      1810.000000
# 75%          ...             4300.000000      2100.000000
# max          ...            10000.000000      6900.000000
#
#        consfin_credit_limit  consfin_credibility  consfin_org_count_current  \
# count           4457.000000          4457.000000                4457.000000
# mean            9187.009199            76.042630                   4.732331
# std             7371.257043            14.536819                   2.974596
# min                0.000000             0.000000                   0.000000
# 25%             4800.000000            77.000000                   2.000000
# 50%             7700.000000            79.000000                   4.000000
# 75%            11700.000000            80.000000                   7.000000
# max            87100.000000            87.000000                  18.000000
#
#        consfin_product_count  consfin_max_limit  consfin_avg_limit  \
# count            4457.000000        4457.000000        4457.000000
# mean                5.227507       16153.690823        8007.696881
# std                 3.409292       14301.037628        5679.418585
# min                 0.000000           0.000000           0.000000
# 25%                 3.000000        7800.000000        4737.000000
# 50%                 5.000000       13800.000000        7050.000000
# 75%                 7.000000       20400.000000       10000.000000
# max                20.000000      266400.000000       82800.000000
#
#        latest_query_day  loans_latest_day
# count       4450.000000       4457.000000
# mean          24.112809         55.181512
# std           37.725724         53.486408
# min           -2.000000         -2.000000
# 25%            5.000000         10.000000
# 50%           14.000000         36.000000
# 75%           24.000000         91.000000
# max          360.000000        323.000000
#
# [8 rows x 83 columns]

# %% [markdown]
# ### 2.发现像Unnamed: 0， bank_card_no， source 这几个特征只有1个值，可以直接dropr掉

# %%
data.describe(include=[np.object])
# Out:
#                                 trade_no bank_card_no reg_preference_for_trad  \
# count                               4754         4754                    4752
# unique                              4754            1                       5
# top     20180507121444807000000023076647          卡号1                    一线城市
# freq                                   1         4754                    3403
#
#        source id_name latest_query_time loans_latest_time
# count    4754    4478              4450              4457
# unique      1    4309               207               232
# top        xs      张龙        2018-04-14        2018-05-03
# freq     4754       5               423               134

# %%
data.groupby(['reg_preference_for_trad'])['status'].mean()
# Out:
# reg_preference_for_trad
# 一线城市    0.248310
# 三线城市    0.258459
# 二线城市    0.198473
# 其他城市    0.500000
# 境外      0.300000
# Name: status, dtype: float64

# %%
data.shape
# Out:
# (4754, 90)

# %%
data.dtypes.value_counts()
# Out:
# float64    70
# int64      13
# object      7
# dtype: int64

# %% [markdown]
# ### 3.发现一线城市未逾期的比较多，感觉这个特征应该比较有用

# %%
grid = sns.FacetGrid(data, row='reg_preference_for_trad', col='status')
grid.map(plt.hist, 'first_transaction_time')

# %% [markdown]
# ### 4.看了下特征的相关性

# %%
corrmat = data.corr()
f, ax = plt.subplots(figsize=(20, 10))
sns.heatmap(corrmat, vmax=.8, square=True)

# %%
corrmat.nlargest(n=10, columns='status')['status']
# Out:
# status                                     1.000000
# trans_fail_top_count_enum_last_1_month     0.332256
# history_fail_fee                           0.320033
# loans_overdue_count                        0.279125
# latest_one_month_fail                      0.257269
# rank_trad_1_month                          0.147258
# trans_fail_top_count_enum_last_6_month     0.133477
# trans_fail_top_count_enum_last_12_month    0.117161
# top_trans_count_last_1_month               0.117113
# trans_day_last_12_month                    0.078892
# Name: status, dtype: float64

# %%
cols = corrmat.nlargest(n=10, columns='status').index

# %%
corrmat = data[cols].corr()
f, ax = plt.subplots(figsize=(20, 10))
sns.heatmap(corrmat, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)

# %% [markdown]
# ### 5.看了下缺失值的情况, student_feature空值不是学生处理，处理成0

# %%
missing_data = data.isnull().sum()
missing_percent = data.isnull().sum() / data.isnull().count()
missing_type = data.dtypes
df_missing = pd.concat([missing_data, missing_percent, missing_type], axis=1)
df_missing = df_missing.rename(columns={0: 'count', 1: 'percent', 2: 'type'})

df_missing = df_missing[df_missing['count']>0]

df_missing = df_missing.sort_values(by=['percent'], ascending=False)

# %%
data['student_feature'] = data['student_feature'].fillna(0)

# %%
df_missing
# Out:
#                                          count   percent     type
# student_feature                           2998  0.630627  float64
# cross_consume_count_last_1_month           426  0.089609  float64
# query_cash_count                           304  0.063946  float64
# latest_six_month_apply                     304  0.063946  float64
# latest_one_month_apply                     304  0.063946  float64
# latest_query_time                          304  0.063946   object
# query_sum_count                            304  0.063946  float64
# query_finance_count                        304  0.063946  float64
# query_org_count                            304  0.063946  float64
# apply_credibility                          304  0.063946  float64
# apply_score                                304  0.063946  float64
# latest_three_month_apply                   304  0.063946  float64
# latest_query_day                           304  0.063946  float64
# loans_product_count                        297  0.062474  float64
# loans_org_count_current                    297  0.062474  float64
# consfin_avg_limit                          297  0.062474  float64
# consfin_max_limit                          297  0.062474  float64
# loans_score                                297  0.062474  float64
# consfin_product_count                      297  0.062474  float64
# consfin_org_count_current                  297  0.062474  float64
# consfin_credibility                        297  0.062474  float64
# consfin_credit_limit                       297  0.062474  float64
# loans_credibility_behavior                 297  0.062474  float64
# loans_count                                297  0.062474  float64
# loans_settle_count                         297  0.062474  float64
# loans_overdue_count                        297  0.062474  float64
# loans_org_count_behavior                   297  0.062474  float64
# consfin_org_count_behavior                 297  0.062474  float64
# loans_cash_count                           297  0.062474  float64
# latest_one_month_loan                      297  0.062474  float64
# ...                                        ...       ...      ...
# avg_price_top_last_12_valid_month          104  0.021876  float64
# consume_mini_time_last_1_month              26  0.005469  float64
# trans_fail_top_count_enum_last_1_month      16  0.003366  float64
# trans_fail_top_count_enum_last_6_month      16  0.003366  float64
# trans_fail_top_count_enum_last_12_month     16  0.003366  float64
# railway_consume_count_last_12_month         12  0.002524  float64
# jewelry_consume_count_last_6_month          12  0.002524  float64
# max_consume_count_later_6_month              8  0.001683  float64
# trans_days_interval_filter                   8  0.001683  float64
# consume_top_time_last_1_month                8  0.001683  float64
# trans_top_time_last_6_month                  8  0.001683  float64
# trans_top_time_last_1_month                  8  0.001683  float64
# consume_top_time_last_6_month                8  0.001683  float64
# trans_amount_increase_rate_lately            3  0.000631  float64
# transd_mcc                                   2  0.000421  float64
# trans_days_interval                          2  0.000421  float64
# middle_volume_percent                        2  0.000421  float64
# trans_activity_day                           2  0.000421  float64
# number_of_trans_from_2011                    2  0.000421  float64
# trans_activity_month                         2  0.000421  float64
# regional_mobility                            2  0.000421  float64
# reg_preference_for_trad                      2  0.000421   object
# first_transaction_time                       2  0.000421  float64
# historical_trans_day                         2  0.000421  float64
# rank_trad_1_month                            2  0.000421  float64
# avg_consume_less_12_valid_month              2  0.000421  float64
# top_trans_count_last_1_month                 2  0.000421  float64
# first_transaction_day                        2  0.000421  float64
# trans_day_last_12_month                      2  0.000421  float64
# low_volume_percent                           2  0.000421  float64
#
# [74 rows x 3 columns]

# %%
df_missing.plot.bar(figsize=(20, 5))

# %%
df_missing.index.intersection(cols)
# Out:
# Index(['loans_overdue_count', 'history_fail_fee', 'latest_one_month_fail',
#        'trans_fail_top_count_enum_last_1_month',
#        'trans_fail_top_count_enum_last_6_month',
#        'trans_fail_top_count_enum_last_12_month', 'rank_trad_1_month',
#        'top_trans_count_last_1_month', 'trans_day_last_12_month'],
#       dtype='object')

# %% [markdown]
# ### 6.drop掉感觉没用的特征，用平均数填充空值，把仅有的文本特征处理成one-hoto类型

# %%
data = data.dropna(subset=['history_fail_fee'])

# %%
data = data.drop(columns=['Unnamed: 0', 'bank_card_no', 'source', 'trade_no', 'custid', 'first_transaction_time', 'id_name', 'latest_query_time', 'loans_latest_time'])

# %%
data = data.fillna(data.mean())

# %%
data.shape
# Out:
# (4457, 81)

# %%
data = pd.get_dummies(data, drop_first=True, dummy_na=True)

# %%
data.isnull().sum().max()
# Out:
# 0

# %% [markdown]
# ### 7.用不同模型交叉验证，随机森林和决策树得分最高

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix,recall_score,classification_report
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import KFold

# %%
kf = KFold(n_splits=3, random_state=1)
preds = {}
models = [KNeighborsClassifier(n_neighbors=3), LogisticRegression(), LinearSVC(), DecisionTreeClassifier(), RandomForestClassifier(n_estimators=25), MLPClassifier(hidden_layer_sizes=(10, 10, 10), activation='relu', max_iter=1000)]
names = ['KNeighbor','LogisticRegression','LinearSVC','DecisionTree','RandomForest','Nerual']
for i, model in enumerate(models):
    predictions = []
    for tr, va in kf.split(data):
        train_x, train_y = data.iloc[tr], data['status'].iloc[tr]
        valid_x, valid_y = data.iloc[va], data['status'].iloc[va]
        model.fit(train_x, train_y)
        accu = model.score(valid_x, valid_y)
        predictions.append(accu)
    plt.plot(predictions)
    plt.legend(names, loc='best')
    print(names[i], np.mean(predictions))
# Out:
# KNeighbor 0.6742159141889963
# LogisticRegression 0.7778761142152798
# LinearSVC 0.6134411257784969
# DecisionTree 1.0
# RandomForest 1.0
# Nerual 0.6219489647484263

# %% [markdown]
# ### 8.不用交叉验证，直接切分训练集和测试集，模型评估随机森林效果最好

# %%
X = data.drop('status', axis=1)
y = data['status']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=.33)

# %%
models = [KNeighborsClassifier(n_neighbors=3), LogisticRegression(), LinearSVC(), DecisionTreeClassifier(), RandomForestClassifier(n_estimators=25), MLPClassifier(hidden_layer_sizes=(10, 10, 10), activation='relu', max_iter=1000)]
names = ['KNeighbor','LogisticRegression','LinearSVC','DecisionTree','RandomForest','Nerual']
for i, model in enumerate(models):
    model.fit(X_train, y_train)
    accu = model.score(X_test, y_test)
    print(names[i], accu)
# Out:
# KNeighbor 0.6505778382053025
# LogisticRegression 0.7797416723317471
# LinearSVC 0.6383412644459552
# DecisionTree 0.6859279401767505
# RandomForest 0.7899388171312033
# Nerual 0.6397008837525493

# %% [markdown]
# ### 9.做了归一化处理，大多数模型的得分反正下降了，这个没有搞明白，有知道的给说下

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(X)
X = scaler.transform(X)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
models = [KNeighborsClassifier(n_neighbors=3), LogisticRegression(), LinearSVC(), DecisionTreeClassifier(), RandomForestClassifier(n_estimators=25), MLPClassifier(hidden_layer_sizes=(10, 10, 10), activation='relu', max_iter=1000)]
names = ['KNeighbor','LogisticRegression','LinearSVC','DecisionTree','RandomForest','Nerual']
for i, model in enumerate(models):
    model.fit(X_train, y_train)
    accu = model.score(X_test, y_test)
    print(names[i], accu)
# Out:
# KNeighbor 0.7511896668932699
# LogisticRegression 0.2494901427600272
# LinearSVC 0.2494901427600272
# DecisionTree 0.24881033310673012
# RandomForest 0.7362338545207342
# Nerual 0.7511896668932699
